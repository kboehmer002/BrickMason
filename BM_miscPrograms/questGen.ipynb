# %%
import docx
from pprint import pprint
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rikki\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from Questgen import main
qe= main.BoolQGen()

# %%
doc = docx.Document('BS2.docx')

# %%
text_list = []

for paragraph in doc.paragraphs:
    text_list.append(paragraph.text.strip())

# %%
dict_list = [{'input_text': text} for text in text_list]

# %%
# Boolean questions - potential to use as an objective list and as titles in the formatted draft
for dict in dict_list:
    output = qe.predict_boolq(dict)
    pprint (output)
# Out:
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\models\t5\tokenization_t5.py:190: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# {'Boolean Questions': ['Is there such a thing as solar portable tape?',
#                        'Is there such a thing as solar portable tapes?',
#                        'Is there such thing as a solar portable tape?'],
#  'Count': 4,
#  'Text': 'Solar portable tapes work by generating electricity from captured '
#          'photons, which means that electricity is only generated when the sun '
#          'is shining. More so, peak energy usage tends to happen at late '
#          'afternoon or evening, when people are home. Thus, energy conversion '
#          'does not adequately meet demands. There is a need for effective '
#          'solar energy storage. In her seminar, Dr. Jillian Dempsey from UNC '
#          'Chapel Hill discussed her research, which tries to address the '
#          'challenges associated with solar energy conversion and storage.'}
# {'Boolean Questions': ['Is there such a thing as solar energy storage?',
#                        'Is it possible to store solar energy in chemical '
#                        'bonds?',
#                        'Is solar energy stored in the chemical bonds of '
#                        'sugar?'],
#  'Count': 4,
#  'Text': 'She briefly discussed the possibility of using heat or '
#          'electrochemical energy storage to address the issue, but ultimately '
#          'focused on the possibility of storing solar energy within chemical '
#          'bonds. She believed storing energy within chemical bonds was '
#          'intuitively worth pursuing, because plants supply a natural model '
#          'for the process; plants store solar energy in the chemical bonds of '
#          'the sugar or starch they produce. The process could be mimicked '
#          'artificially; solar energy could hypothetically be stored in small, '
#          'energy dense molecules such as hydrogen, methane, or methanol, for '
#          'example.'}
# {'Boolean Questions': ['Can a catalyst be used to convert solar energy to '
#                        'chemical energy?',
#                        'Can a catalyst be used to convert solar energy to '
#                        'electricity?',
#                        'Can a catalyst help convert solar energy to chemical '
#                        'energy?'],
#  'Count': 4,
#  'Text': 'Catalysts would be needed to aid the solar to chemical energy '
#          'conversion process. As one example, she detailed proton reduction to '
#          'dihydrogen via a cobaloxime catalyst. The reaction involves proton '
#          'coupled electron processes that form a cobalt hydride species as an '
#          'intermediate, which then in turn goes on to release H2. While it was '
#          'known that a PCT reaction formed the metal hydride, she explained '
#          'that not much was known about the details of the proton coupled '
#          'electron processes in the reaction. Several potential reaction '
#          'mechanisms could involve either a reduction and then protonation of '
#          'the catalyst, a protonation and then reduction of the catalyst, or a '
#          'concreted proton-electron transfer (CPET) process - where a proton '
#          'and electron are transferred together to the catalyst. Though the '
#          'CPET process has a high kinetic barrier, it can bypass high energy '
#          'intermediates that would form in the other two pathways. '
#          'Furthermore, there are ways to lower the kinetic barrier. Dr. '
#          'Dempsey was therefore interested in developing efficient catalysts '
#          'that operated through CPET pathways.'}
# {'Boolean Questions': ['Is the second step of a cpet reaction slow?',
#                        'Is the second step of a cpet reaction constant?',
#                        'Is the second step of cobalt ii reaction slow?'],
#  'Count': 4,
#  'Text': 'Dr. Dempsey and several undergraduate students used the previously '
#          'detailed electrochemical concepts in studying the reaction mechanism '
#          'involving their cobalt catalyst. Cobalt (II) can be reduced to '
#          'cobalt (I), after which protons are added to solution. High acid '
#          'concentrations result in more positive potentials, which shows that '
#          'reduction to cobalt (I) is followed by a fast protonation to form a '
#          'cobalt (III) hydride, which is reduced to cobalt (II) hydride, which '
#          'then forms a cobalt (II) H2 complex. They expected the second '
#          'protonation to be slow and were able to observe a rate constant and '
#          'use that to get information about the second step. They also found a '
#          'third step, which they posited to be an H2 released, in the '
#          'mechanism that was pH dependent. The goal in finding factors '
#          'influencing the reaction mechanism was make a CPET reaction possible '
#          'under the right conditions. They found that the electron transfer, '
#          'proton transfer mechanism occurs constantly, under a wide range of '
#          'conditions. Changing conditions simply changed the kinetics of the '
#          'reaction, not the mechanism itself.'}
# {'Boolean Questions': ['Is tautomerization the same as cobalt ii?',
#                        'Is cobalt ii a non reactive metal in pct?',
#                        'Is cobalt ii a non reactive element in pct?'],
#  'Count': 4,
#  'Text': 'They next looked at a model system where of a cobalt (III) hydride '
#          'that was non-reactive after formation. The reaction mechanism here '
#          'was found to be reduction of cobalt (II) to cobalt (I) followed by '
#          'protonation to form the cobalt (III) hydride. Both concentration and '
#          'the steric bulk of various acids used was found to affect the '
#          'mechanism, and they found the pathway may include structural '
#          'changes, namely tautomerization. They also focused on a step that '
#          'preceded the formation of the cobalt (II) species, which involved '
#          'the loss of acetonitrile from a cobalt (III) species. Eventually, '
#          'they discovered a barrier to direct protonation of the metal to make '
#          'the metal hydride. Currently, the group is trying to understand the '
#          'kinetic barriers that influences PCT mechanisms, such as the one '
#          'that caused an indirect protonation of the metal.'}
# {'Boolean Questions': ['Is there such a thing as cascade catalysis?',
#                        'Is there such thing as a cascade catalysis?',
#                        'Is there a catalyst for cascade catalysis?'],
#  'Count': 4,
#  'Text': 'After discussing their efforts in forming small molecules that could '
#          'be used in fuels, she briefly discussed how sunlight was used to '
#          'drive the reactions. She explained their goal was to bring together '
#          'the fuel forming catalysts with light absorbing, charge separating '
#          'semi-conductors. In the future, she expects the use of cascade '
#          'catalysis – where multiple catalysts will work together to '
#          'synthesize a multi-carbon lipid fuel. She detailed a few of their '
#          'accomplishments and challenges in this endeavor, as she wrapped up.'}
# {'Boolean Questions': ['Did dr dempsey give a good overview of fuel formation?',
#                        'Did dr dempsey talk about how light drives reactions?',
#                        'Is dr dempsey a professor of chemistry?'],
#  'Count': 4,
#  'Text': 'Overall, the talk was well structured, sufficiently detailed, and '
#          'interesting. Dr. Dempsey was able to explain her research in a way '
#          'that was comprehensible to non-experts in the field, while also '
#          'managing to keep the talk educational and informationally dense. The '
#          'one major criticism I can think of is that she could have more '
#          'evenly prioritized the first part, where she discussed molecular '
#          'synthesis, with the second part, where she discussed the way light '
#          'was used to drive the reactions. She could have summarized their '
#          'research into catalytic mechanisms with a bit less detail. It seemed '
#          'like the discussion of integrating fuel formation (through cascade '
#          'catalysis) with use of light absorbing semi-conductors was more '
#          'relevant to the topic introduced in the introduction, and that it '
#          'was hastily discussed in only the last ten minutes or so. She may '
#          'have just had too much information to present in a one-hour talk.'}

# %%
# Multiple choice questions - append to end of draft
for dict in dict_list:
    qg = main.QGen()
    output = qg.predict_mcq(dict)
    pprint (output)
# Out:
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\tokenization_utils_base.py:2212: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\models\t5\tokenization_t5.py:190: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# Running model for generation
#  Sense2vec_distractors successful for word :  energy usage
#  Sense2vec_distractors successful for word :  photons
#  Sense2vec_distractors successful for word :  electricity
#  Sense2vec_distractors successful for word :  afternoon
# {'questions': [{'answer': 'energy usage',
#                 'context': 'More so, peak energy usage tends to happen at late '
#                            'afternoon or evening, when people are home.',
#                 'extra_options': ['Transmission Losses'],
#                 'id': 1,
#                 'options': ['Energy Consumption',
#                             'Electricity Use',
#                             'Carbon Output'],
#                 'options_algorithm': 'sense2vec',
#                 'question_statement': 'What happens at the end of the day when '
#                                       'people are home?',
#                 'question_type': 'MCQ'},
#                {'answer': 'photons',
#                 'context': 'Solar portable tapes work by generating '
#                            'electricity from captured photons, which means '
#                            'that electricity is only generated when the sun is '
#                            'shining.',
#                 'extra_options': ['Charged Particles',
#                                   'Normal Matter',
#                                   'Em Radiation'],
#                 'id': 2,
#                 'options': ['Single Photon', 'Light Waves', 'Electrons'],
#                 'options_algorithm': 'sense2vec',
#                 'question_statement': 'What do solar portable tapes generate '
#                                       'electricity from?',
#                 'question_type': 'MCQ'},
#                {'answer': 'electricity',
#                 'context': 'Solar portable tapes work by generating '
#                            'electricity from captured photons, which means '
#                            'that electricity is only generated when the sun is '
#                            'shining. Solar portable tapes work by generating '
#                            'electricity from captured photons, which means '
#                            'that electricity is only generated when the sun is '
#                            'shining.',
#                 'extra_options': [],
#                 'id': 3,
#                 'options': ['Electrical Power', 'Solar Cells'],
#                 'options_algorithm': 'sense2vec',
#                 'question_statement': 'What is generated when the sun is '
#                                       'shining?',
#                 'question_type': 'MCQ'},
#                {'answer': 'afternoon',
#                 'context': 'More so, peak energy usage tends to happen at late '
#                            'afternoon or evening, when people are home.',
#                 'extra_options': ['Midday', 'Lunchtime'],
#                 'id': 4,
#                 'options': ['Evening', 'Saturday Morning', 'Noon'],
#                 'options_algorithm': 'sense2vec',
#                 'question_statement': 'When is peak energy usage most likely '
#                                       'to happen?',
#                 'question_type': 'MCQ'}],
#  'statement': 'Solar portable tapes work by generating electricity from '
#               'captured photons, which means that electricity is only '
#               'generated when the sun is shining. More so, peak energy usage '
#               'tends to happen at late afternoon or evening, when people are '
#               'home. Thus, energy conversion does not adequately meet demands. '
#               'There is a need for effective solar energy storage. In her '
#               'seminar, Dr. Jillian Dempsey from UNC Chapel Hill discussed her '
#               'research, which tries to address the challenges associated with '
#               'solar energy conversion and storage.',
#  'time_taken': 61.3311071395874}
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\tokenization_utils_base.py:2212: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\models\t5\tokenization_t5.py:190: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# Running model for generation
#  Sense2vec_distractors successful for word :  energy storage
#  Sense2vec_distractors successful for word :  sugar
#  Sense2vec_distractors successful for word :  bonds
#  Sense2vec_distractors successful for word :  model
# {'questions': [{'answer': 'energy storage',
#                 'context': 'She briefly discussed the possibility of using '
#                            'heat or electrochemical energy storage to address '
#                            'the issue, but ultimately focused on the '
#                            'possibility of storing solar energy within '
#                            'chemical bonds.',
#                 'extra_options': ['Photovoltaics', 'Solar/Wind'],
#                 'id': 1,
#                 'options': ['Power Generation', 'Fuel Cells', 'Energy Sources'],
#                 'options_algorithm': 'sense2vec',
#                 'question_statement': 'What is the use of heat or '
#                                       'electrochemical energy storage?',
#                 'question_type': 'MCQ'},
#                {'answer': 'sugar',
#                 'context': 'She believed storing energy within chemical bonds '
#                            'was intuitively worth pursuing, because plants '
#                            'supply a natural model for the process; plants '
#                            'store solar energy in the chemical bonds of the '
#                            'sugar or starch they produce.',
#                 'extra_options': ['Corn Syrup'],
#                 'id': 2,
#                 'options': ['Fruit Juice', 'Whole Milk', 'Splenda'],
#                 'options_algorithm': 'sense2vec',
#                 'question_statement': 'What is the most natural model for '
#                                       'storing solar energy in chemical bonds?',
#                 'question_type': 'MCQ'},
#                {'answer': 'bonds',
#                 'context': 'She believed storing energy within chemical bonds '
#                            'was intuitively worth pursuing, because plants '
#                            'supply a natural model for the process; plants '
#                            'store solar energy in the chemical bonds of the '
#                            'sugar or starch they produce. She believed storing '
#                            'energy within chemical bonds was intuitively worth '
#                            'pursuing, because plants supply a natural model '
#                            'for the process; plants store solar energy in the '
#                            'chemical bonds of the sugar or starch they '
#                            'produce. She briefly discussed the possibility of '
#                            'using heat or electrochemical energy storage to '
#                            'address the issue, but ultimately focused on the '
#                            'possibility of storing solar energy within '
#                            'chemical bonds.',
#                 'extra_options': ['Bond Funds', 'Stocks'],
#                 'id': 3,
#                 'options': ['Treasuries', 'Existing Money', 'T-Bills'],
#                 'options_algorithm': 'sense2vec',
#                 'question_statement': 'What do plants store solar energy in?',
#                 'question_type': 'MCQ'},
#                {'answer': 'model',
#                 'context': 'She believed storing energy within chemical bonds '
#                            'was intuitively worth pursuing, because plants '
#                            'supply a natural model for the process; plants '
#                            'store solar energy in the chemical bonds of the '
#                            'sugar or starch they produce.',
#                 'extra_options': [],
#                 'id': 4,
#                 'options': ['Design'],
#                 'options_algorithm': 'sense2vec',
#                 'question_statement': 'What do plants provide for the process '
#                                       'of storing energy within chemical '
#                                       'bonds?',
#                 'question_type': 'MCQ'}],
#  'statement': 'She briefly discussed the possibility of using heat or '
#               'electrochemical energy storage to address the issue, but '
#               'ultimately focused on the possibility of storing solar energy '
#               'within chemical bonds. She believed storing energy within '
#               'chemical bonds was intuitively worth pursuing, because plants '
#               'supply a natural model for the process; plants store solar '
#               'energy in the chemical bonds of the sugar or starch they '
#               'produce. The process could be mimicked artificially; solar '
#               'energy could hypothetically be stored in small, energy dense '
#               'molecules such as hydrogen, methane, or methanol, for example.',
#  'time_taken': 49.20694828033447}
# {}

# %%
# Generate FAQs - also potential for section titles or objectives in the formatted draft
for dict in dict_list:
    output = qg.predict_shortq(dict)
    pprint (output)
# Out:
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\tokenization_utils_base.py:2212: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\models\t5\tokenization_t5.py:190: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# Running model for generation
# {'questions': [{'Question': 'What happens at the end of the day when people are home?', 'Answer': 'energy usage', 'id': 1, 'context': 'More so, peak energy usage tends to happen at late afternoon or evening, when people are home.'}, {'Question': 'What do solar portable tapes generate electricity from?', 'Answer': 'photons', 'id': 2, 'context': 'Solar portable tapes work by generating electricity from captured photons, which means that electricity is only generated when the sun is shining.'}, {'Question': 'What is generated when the sun is shining?', 'Answer': 'electricity', 'id': 3, 'context': 'Solar portable tapes work by generating electricity from captured photons, which means that electricity is only generated when the sun is shining. Solar portable tapes work by generating electricity from captured photons, which means that electricity is only generated when the sun is shining.'}, {'Question': 'When is peak energy usage most likely to happen?', 'Answer': 'afternoon', 'id': 4, 'context': 'More so, peak energy usage tends to happen at late afternoon or evening, when people are home.'}]}
# {'questions': [{'Answer': 'energy usage',
#                 'Question': 'What happens at the end of the day when people '
#                             'are home?',
#                 'context': 'More so, peak energy usage tends to happen at late '
#                            'afternoon or evening, when people are home.',
#                 'id': 1},
#                {'Answer': 'photons',
#                 'Question': 'What do solar portable tapes generate electricity '
#                             'from?',
#                 'context': 'Solar portable tapes work by generating '
#                            'electricity from captured photons, which means '
#                            'that electricity is only generated when the sun is '
#                            'shining.',
#                 'id': 2},
#                {'Answer': 'electricity',
#                 'Question': 'What is generated when the sun is shining?',
#                 'context': 'Solar portable tapes work by generating '
#                            'electricity from captured photons, which means '
#                            'that electricity is only generated when the sun is '
#                            'shining. Solar portable tapes work by generating '
#                            'electricity from captured photons, which means '
#                            'that electricity is only generated when the sun is '
#                            'shining.',
#                 'id': 3},
#                {'Answer': 'afternoon',
#                 'Question': 'When is peak energy usage most likely to happen?',
#                 'context': 'More so, peak energy usage tends to happen at late '
#                            'afternoon or evening, when people are home.',
#                 'id': 4}],
#  'statement': 'Solar portable tapes work by generating electricity from '
#               'captured photons, which means that electricity is only '
#               'generated when the sun is shining. More so, peak energy usage '
#               'tends to happen at late afternoon or evening, when people are '
#               'home. Thus, energy conversion does not adequately meet demands. '
#               'There is a need for effective solar energy storage. In her '
#               'seminar, Dr. Jillian Dempsey from UNC Chapel Hill discussed her '
#               'research, which tries to address the challenges associated with '
#               'solar energy conversion and storage.'}
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\tokenization_utils_base.py:2212: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\models\t5\tokenization_t5.py:190: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# Running model for generation
# {'questions': [{'Question': 'What is the use of heat or electrochemical energy storage?', 'Answer': 'energy storage', 'id': 1, 'context': 'She briefly discussed the possibility of using heat or electrochemical energy storage to address the issue, but ultimately focused on the possibility of storing solar energy within chemical bonds.'}, {'Question': 'What is the most natural model for storing solar energy in chemical bonds?', 'Answer': 'sugar', 'id': 2, 'context': 'She believed storing energy within chemical bonds was intuitively worth pursuing, because plants supply a natural model for the process; plants store solar energy in the chemical bonds of the sugar or starch they produce.'}, {'Question': 'What do plants store solar energy in?', 'Answer': 'bonds', 'id': 3, 'context': 'She believed storing energy within chemical bonds was intuitively worth pursuing, because plants supply a natural model for the process; plants store solar energy in the chemical bonds of the sugar or starch they produce. She believed storing energy within chemical bonds was intuitively worth pursuing, because plants supply a natural model for the process; plants store solar energy in the chemical bonds of the sugar or starch they produce. She briefly discussed the possibility of using heat or electrochemical energy storage to address the issue, but ultimately focused on the possibility of storing solar energy within chemical bonds.'}, {'Question': 'What do plants provide for the process of storing energy within chemical bonds?', 'Answer': 'model', 'id': 4, 'context': 'She believed storing energy within chemical bonds was intuitively worth pursuing, because plants supply a natural model for the process; plants store solar energy in the chemical bonds of the sugar or starch they produce.'}]}
# {'questions': [{'Answer': 'energy storage',
#                 'Question': 'What is the use of heat or electrochemical energy '
#                             'storage?',
#                 'context': 'She briefly discussed the possibility of using '
#                            'heat or electrochemical energy storage to address '
#                            'the issue, but ultimately focused on the '
#                            'possibility of storing solar energy within '
#                            'chemical bonds.',
#                 'id': 1},
#                {'Answer': 'sugar',
#                 'Question': 'What is the most natural model for storing solar '
#                             'energy in chemical bonds?',
#                 'context': 'She believed storing energy within chemical bonds '
#                            'was intuitively worth pursuing, because plants '
#                            'supply a natural model for the process; plants '
#                            'store solar energy in the chemical bonds of the '
#                            'sugar or starch they produce.',
#                 'id': 2},
#                {'Answer': 'bonds',
#                 'Question': 'What do plants store solar energy in?',
#                 'context': 'She believed storing energy within chemical bonds '
#                            'was intuitively worth pursuing, because plants '
#                            'supply a natural model for the process; plants '
#                            'store solar energy in the chemical bonds of the '
#                            'sugar or starch they produce. She believed storing '
#                            'energy within chemical bonds was intuitively worth '
#                            'pursuing, because plants supply a natural model '
#                            'for the process; plants store solar energy in the '
#                            'chemical bonds of the sugar or starch they '
#                            'produce. She briefly discussed the possibility of '
#                            'using heat or electrochemical energy storage to '
#                            'address the issue, but ultimately focused on the '
#                            'possibility of storing solar energy within '
#                            'chemical bonds.',
#                 'id': 3},
#                {'Answer': 'model',
#                 'Question': 'What do plants provide for the process of storing '
#                             'energy within chemical bonds?',
#                 'context': 'She believed storing energy within chemical bonds '
#                            'was intuitively worth pursuing, because plants '
#                            'supply a natural model for the process; plants '
#                            'store solar energy in the chemical bonds of the '
#                            'sugar or starch they produce.',
#                 'id': 4}],
#  'statement': 'She briefly discussed the possibility of using heat or '
#               'electrochemical energy storage to address the issue, but '
#               'ultimately focused on the possibility of storing solar energy '
#               'within chemical bonds. She believed storing energy within '
#               'chemical bonds was intuitively worth pursuing, because plants '
#               'supply a natural model for the process; plants store solar '
#               'energy in the chemical bonds of the sugar or starch they '
#               'produce. The process could be mimicked artificially; solar '
#               'energy could hypothetically be stored in small, energy dense '
#               'molecules such as hydrogen, methane, or methanol, for example.'}
# ZERO
# {}
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\tokenization_utils_base.py:2212: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\models\t5\tokenization_t5.py:190: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# Running model for generation
# {'questions': [{'Question': 'What is the cobalt (III) hydride, which is reduced to cobalt (II) hydride, which then forms a cobalt (II) H2 complex?', 'Answer': 'iii', 'id': 1, 'context': 'High acid concentrations result in more positive potentials, which shows that reduction to cobalt (I) is followed by a fast protonation to form a cobalt (III) hydride, which is reduced to cobalt (II) hydride, which then forms a cobalt (II) H2 complex.'}, {'Question': 'What is added to solution after cobalt is reduced to cobalt (I)?', 'Answer': 'protons', 'id': 2, 'context': 'Cobalt (II) can be reduced to cobalt (I), after which protons are added to solution.'}]}
# {'questions': [{'Answer': 'iii',
#                 'Question': 'What is the cobalt (III) hydride, which is '
#                             'reduced to cobalt (II) hydride, which then forms '
#                             'a cobalt (II) H2 complex?',
#                 'context': 'High acid concentrations result in more positive '
#                            'potentials, which shows that reduction to cobalt '
#                            '(I) is followed by a fast protonation to form a '
#                            'cobalt (III) hydride, which is reduced to cobalt '
#                            '(II) hydride, which then forms a cobalt (II) H2 '
#                            'complex.',
#                 'id': 1},
#                {'Answer': 'protons',
#                 'Question': 'What is added to solution after cobalt is reduced '
#                             'to cobalt (I)?',
#                 'context': 'Cobalt (II) can be reduced to cobalt (I), after '
#                            'which protons are added to solution.',
#                 'id': 2}],
#  'statement': 'Dr. Dempsey and several undergraduate students used the '
#               'previously detailed electrochemical concepts in studying the '
#               'reaction mechanism involving their cobalt catalyst. Cobalt (II) '
#               'can be reduced to cobalt (I), after which protons are added to '
#               'solution. High acid concentrations result in more positive '
#               'potentials, which shows that reduction to cobalt (I) is '
#               'followed by a fast protonation to form a cobalt (III) hydride, '
#               'which is reduced to cobalt (II) hydride, which then forms a '
#               'cobalt (II) H2 complex. They expected the second protonation to '
#               'be slow and were able to observe a rate constant and use that '
#               'to get information about the second step. They also found a '
#               'third step, which they posited to be an H2 released, in the '
#               'mechanism that was pH dependent. The goal in finding factors '
#               'influencing the reaction mechanism was make a CPET reaction '
#               'possible under the right conditions. They found that the '
#               'electron transfer, proton transfer mechanism occurs constantly, '
#               'under a wide range of conditions. Changing conditions simply '
#               'changed the kinetics of the reaction, not the mechanism itself.'}
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\tokenization_utils_base.py:2212: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\models\t5\tokenization_t5.py:190: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# Running model for generation
# {'questions': [{'Question': 'What is the step that preceded the formation of cobalt?', 'Answer': 'iii', 'id': 1, 'context': 'They also focused on a step that preceded the formation of the cobalt (II) species, which involved the loss of acetonitrile from a cobalt (III) species. The reaction mechanism here was found to be reduction of cobalt (II) to cobalt (I) followed by protonation to form the cobalt (III) hydride. They next looked at a model system where of a cobalt (III) hydride that was non-reactive after formation.'}, {'Question': 'What is the loss of acetonitrile from a cobalt (III) species?', 'Answer': 'cobalt', 'id': 2, 'context': 'They also focused on a step that preceded the formation of the cobalt (II) species, which involved the loss of acetonitrile from a cobalt (III) species. They also focused on a step that preceded the formation of the cobalt (II) species, which involved the loss of acetonitrile from a cobalt (III) species. The reaction mechanism here was found to be reduction of cobalt (II) to cobalt (I) followed by protonation to form the cobalt (III) hydride.'}]}
# {'questions': [{'Answer': 'iii',
#                 'Question': 'What is the step that preceded the formation of '
#                             'cobalt?',
#                 'context': 'They also focused on a step that preceded the '
#                            'formation of the cobalt (II) species, which '
#                            'involved the loss of acetonitrile from a cobalt '
#                            '(III) species. The reaction mechanism here was '
#                            'found to be reduction of cobalt (II) to cobalt (I) '
#                            'followed by protonation to form the cobalt (III) '
#                            'hydride. They next looked at a model system where '
#                            'of a cobalt (III) hydride that was non-reactive '
#                            'after formation.',
#                 'id': 1},
#                {'Answer': 'cobalt',
#                 'Question': 'What is the loss of acetonitrile from a cobalt '
#                             '(III) species?',
#                 'context': 'They also focused on a step that preceded the '
#                            'formation of the cobalt (II) species, which '
#                            'involved the loss of acetonitrile from a cobalt '
#                            '(III) species. They also focused on a step that '
#                            'preceded the formation of the cobalt (II) species, '
#                            'which involved the loss of acetonitrile from a '
#                            'cobalt (III) species. The reaction mechanism here '
#                            'was found to be reduction of cobalt (II) to cobalt '
#                            '(I) followed by protonation to form the cobalt '
#                            '(III) hydride.',
#                 'id': 2}],
#  'statement': 'They next looked at a model system where of a cobalt (III) '
#               'hydride that was non-reactive after formation. The reaction '
#               'mechanism here was found to be reduction of cobalt (II) to '
#               'cobalt (I) followed by protonation to form the cobalt (III) '
#               'hydride. Both concentration and the steric bulk of various '
#               'acids used was found to affect the mechanism, and they found '
#               'the pathway may include structural changes, namely '
#               'tautomerization. They also focused on a step that preceded the '
#               'formation of the cobalt (II) species, which involved the loss '
#               'of acetonitrile from a cobalt (III) species. Eventually, they '
#               'discovered a barrier to direct protonation of the metal to make '
#               'the metal hydride. Currently, the group is trying to understand '
#               'the kinetic barriers that influences PCT mechanisms, such as '
#               'the one that caused an indirect protonation of the metal.'}
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\tokenization_utils_base.py:2212: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\models\t5\tokenization_t5.py:190: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# Running model for generation
# {'questions': [{'Question': 'What is the main use of sunlight?', 'Answer': 'fuels', 'id': 1, 'context': 'After discussing their efforts in forming small molecules that could be used in fuels, she briefly discussed how sunlight was used to drive the reactions.'}, {'Question': 'What is the light absorbing, charge separating semi-conductors?', 'Answer': 'absorbing', 'id': 2, 'context': 'She explained their goal was to bring together the fuel forming catalysts with light absorbing, charge separating semi-conductors.'}]}
# {'questions': [{'Answer': 'fuels',
#                 'Question': 'What is the main use of sunlight?',
#                 'context': 'After discussing their efforts in forming small '
#                            'molecules that could be used in fuels, she briefly '
#                            'discussed how sunlight was used to drive the '
#                            'reactions.',
#                 'id': 1},
#                {'Answer': 'absorbing',
#                 'Question': 'What is the light absorbing, charge separating '
#                             'semi-conductors?',
#                 'context': 'She explained their goal was to bring together the '
#                            'fuel forming catalysts with light absorbing, '
#                            'charge separating semi-conductors.',
#                 'id': 2}],
#  'statement': 'After discussing their efforts in forming small molecules that '
#               'could be used in fuels, she briefly discussed how sunlight was '
#               'used to drive the reactions. She explained their goal was to '
#               'bring together the fuel forming catalysts with light absorbing, '
#               'charge separating semi-conductors. In the future, she expects '
#               'the use of cascade catalysis – where multiple catalysts will '
#               'work together to synthesize a multi-carbon lipid fuel. She '
#               'detailed a few of their accomplishments and challenges in this '
#               'endeavor, as she wrapped up.'}
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\tokenization_utils_base.py:2212: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# e:\stuff\GitPlayground\questGen\.conda\lib\site-packages\transformers\models\t5\tokenization_t5.py:190: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# Running model for generation
# {'questions': [{'Question': 'What is the main research area of catalytic mechanisms?', 'Answer': 'mechanisms', 'id': 1, 'context': 'She could have summarized their research into catalytic mechanisms with a bit less detail.'}, {'Question': 'What could have been added to the research on catalytic mechanisms?', 'Answer': 'detail', 'id': 2, 'context': 'She could have summarized their research into catalytic mechanisms with a bit less detail.'}]}
# {'questions': [{'Answer': 'mechanisms',
#                 'Question': 'What is the main research area of catalytic '
#                             'mechanisms?',
#                 'context': 'She could have summarized their research into '
#                            'catalytic mechanisms with a bit less detail.',
#                 'id': 1},
#                {'Answer': 'detail',
#                 'Question': 'What could have been added to the research on '
#                             'catalytic mechanisms?',
#                 'context': 'She could have summarized their research into '
#                            'catalytic mechanisms with a bit less detail.',
#                 'id': 2}],
#  'statement': 'Overall, the talk was well structured, sufficiently detailed, '
#               'and interesting. Dr. Dempsey was able to explain her research '
#               'in a way that was comprehensible to non-experts in the field, '
#               'while also managing to keep the talk educational and '
#               'informationally dense. The one major criticism I can think of '
#               'is that she could have more evenly prioritized the first part, '
#               'where she discussed molecular synthesis, with the second part, '
#               'where she discussed the way light was used to drive the '
#               'reactions. She could have summarized their research into '
#               'catalytic mechanisms with a bit less detail. It seemed like the '
#               'discussion of integrating fuel formation (through cascade '
#               'catalysis) with use of light absorbing semi-conductors was more '
#               'relevant to the topic introduced in the introduction, and that '
#               'it was hastily discussed in only the last ten minutes or so. '
#               'She may have just had too much information to present in a '
#               'one-hour talk.'}
